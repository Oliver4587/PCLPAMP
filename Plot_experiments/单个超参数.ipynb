# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimSun']
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 7.5

# 数据
lengths = [1, 5, 10, 15, 20, 30, 40, 50]
sensitivity = [90.44205496, 89.96415771, 88.64994026, 90.32258065, 92.47, 89.12783751, 92.23416965, 89.0083632]
specificity = [94.62365591, 95.34050179, 95.10155317, 94.38470729, 95.82, 95.45997611, 93.90681004, 96.2962963]
accuracy = [92.53285544, 92.65232975, 91.87574671, 92.35364397, 94.15, 92.29390681, 93.07048984, 92.65232975]
f1_score = [92.37339841, 92.44935543, 91.60493827, 92.19512195, 94.05, 92.04194941, 93.01204819, 92.37445753]
mcc = [85.14018059, 85.4282143, 83.92634016, 84.77726175, 88.34, 84.75790686, 86.15303216, 85.53210941]
auroc = [95.85222869, 96.17161193, 96.46201873, 95.64282747, 97.2, 95.04631235, 96.87882279, 96.38722239]

# 绘制
plt.figure(figsize=(12, 8))

plt.plot(lengths, sensitivity, marker='o', color='b', label='SN',markersize=8)
plt.plot(lengths, specificity, marker='s', color='g', label='SP',markersize=8)
plt.plot(lengths, accuracy, marker='D', color='r', label='ACC',markersize=8)
plt.plot(lengths, f1_score, marker='^', color='c', label='F1',markersize=8)
plt.plot(lengths, mcc, marker='v', color='m', label='MCC',markersize=8)
plt.plot(lengths, auroc, marker='P', color='y', label='AUROC',markersize=8)

# 图例和标签
plt.xlabel('$l$取值', fontsize=18)
plt.ylabel('性能指标 (%)', fontsize=18)
# plt.legend(fontsize=12, bbox_to_anchor=(1.0, 1), loc='upper left')  # 将图例放置在图表外部
plt.legend(fontsize=15, bbox_to_anchor=(0.5, 1.1), loc='upper center',ncol=6)  # 将图例放置在图表外部
plt.grid(False)  # 去掉网格线

# 设置纵坐标为百分比，并设置字体大小
# plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0f}%'.format(y)))
plt.tick_params(axis='y', labelsize=18)
plt.xticks(fontsize=18)

# 保存为高清图片
plt.savefig('../Figures/INDEP/color/超参数分析-提示长度.svg', bbox_inches='tight', dpi=600)

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimSun']
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 7.5
# 数据
lambdas = [0, 0.3, 0.5, 0.8, 1]
sensitivity = [92.23, 91.64, 90.2, 92.47, 92.47]
specificity = [90.32, 93.67, 95.22, 94.38, 95.82]
accuracy = [91.28, 92.65, 92.71, 93.43, 94.15]
f1_score = [91.36, 92.58, 92.52, 93.37, 94.05]
mcc = [82.57, 85.32, 85.53, 86.87, 88.34]
auroc = [94.9, 95.34, 96.89, 95.63, 97.2]

# 绘制
plt.figure(figsize=(10, 6))

plt.plot(lambdas, sensitivity, marker='o', color='b', label='SN',markersize=8)
plt.plot(lambdas, specificity, marker='s', color='g', label='SP',markersize=8)
plt.plot(lambdas, accuracy, marker='D', color='r', label='ACC',markersize=8)
plt.plot(lambdas, f1_score, marker='^', color='c', label='F1',markersize=8)
plt.plot(lambdas, mcc, marker='v', color='m', label='MCC',markersize=8)
plt.plot(lambdas, auroc, marker='P', color='y', label='AUROC',markersize=8)

# 图例和标签
plt.xlabel('$λ$取值', fontsize=18)
plt.ylabel('性能指标 (%)', fontsize=18)
# plt.title('不同λ取值下的模型性能', fontsize=16)
plt.legend(fontsize=12)
plt.grid(False)  # 去掉网格线
plt.legend(fontsize=15, bbox_to_anchor=(0.5, 1.12), loc='upper center',ncol=6)  # 将图例放置在图表外部
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# 保存图表
# plt.savefig('../Figures/INDEP/Compared_Lambda.svg', dpi=600,bbox_inches='tight')
plt.savefig('../Figures/INDEP/color/超参数分析-λ取值.svg', bbox_inches='tight', dpi=600)

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
m_values = [1.0, 3.0, 5.0, 8.0, 10.0]
sensitivity = [92.11, 90.08, 91.52, 92.47, 93.07]
specificity = [91.40, 94.15, 94.98, 95.82, 92.95]
accuracy = [91.76, 92.11, 93.25, 94.15, 93.01]
f1_score = [91.79, 91.95, 93.13, 94.05, 93.01]
mcc = [83.51, 84.30, 86.55, 88.34, 86.02]
auroc = [96.63, 96.87, 96.68, 97.20, 95.49]

# 绘制
plt.figure(figsize=(10, 6))

plt.plot(m_values, sensitivity, marker='o', color='b', label='SN',markersize=8)
plt.plot(m_values, specificity, marker='s', color='g', label='SP',markersize=8)
plt.plot(m_values, accuracy, marker='D', color='r', label='ACC',markersize=8)
plt.plot(m_values, f1_score, marker='^', color='c', label='F1',markersize=8)
plt.plot(m_values, mcc, marker='v', color='m', label='MCC',markersize=8)
plt.plot(m_values, auroc, marker='P', color='y', label='AUROC',markersize=8)

# 图例和标签
plt.xlabel('$m$取值', fontsize=18)
plt.ylabel('性能指标 (%)', fontsize=18)
# plt.title('不同m取值下的模型性能')
plt.legend(fontsize=12)
plt.grid(False)  # 去掉网格线
plt.legend(fontsize=15, bbox_to_anchor=(0.5, 1.12), loc='upper center',ncol=6)  # 将图例放置在图表外部

# 设置纵坐标为百分比，并设置字体大小
# plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0f}%'.format(y)))
plt.tick_params(axis='y', labelsize=18)
plt.xticks(fontsize=18)

# 保存为高清图片
# plt.savefig('../Figures/INDEP/Compared_Margin.svg', dpi=600,bbox_inches='tight')
plt.savefig('../Figures/INDEP/color/超参数分析-m取值.svg', bbox_inches='tight', dpi=600)

# 显示图表
plt.show()
